# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

# %%
import sys
import warnings
warnings.simplefilter('ignore')

print(__doc__)

#Load dataset
breast_cancer = datasets.load_breast_cancer()
# Out:
# Automatically created module for IPython interactive environment

# %%
X = breast_cancer.data
y = breast_cancer.target
labelencoder_Y = LabelEncoder()
y = labelencoder_Y.fit_transform(y)
# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=0)
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
tuned_parameters = [{'max_depth': [1,10, 100, 1000],
                     'min_samples_split': [2,4,5,10,15,20],
                     'min_samples_leaf': [1,2,5,10,15],
                     'min_impurity_decrease': [0,0.01,0.001,0.0001]}]

scores = ['precision', 'recall']


for score in scores:

  print("#Tuning")
  print()
  cv_list = [5,10,15,20,25]
  for cv1 in cv_list:

    clf = GridSearchCV(DecisionTreeClassifier(), tuned_parameters, cv= cv1, scoring='%s_macro' % score)

    clf.fit(X_train, y_train)

    print("Best parameters set found on set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on dev set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']

    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
      print("%0.3f (+/-%0.03f) for %r" % (mean, std*2, params))


    print()
    print("Classification report:")



    y_true, y_pred = y_test, clf.predict(X_test)

    print(classification_report(y_true, y_pred))
    print()
# Out:
# #Tuning
#
# Best parameters set found on set:
#
# {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Grid scores on dev set:
#
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 10, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 10, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 10, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 10, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 10, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 10, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 2}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 4}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 5}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 10}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 15}
# 0.892 (+/-0.069) for {'max_depth': 1, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 20}
# 0.914 (+/-0.116) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.909 (+/-0.123) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.902 (+/-0.099) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.904 (+/-0.098) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.902 (+/-0.093) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 15}
# 0.881 (+/-0.140) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.904 (+/-0.034) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.896 (+/-0.113) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 4}
# 0.892 (+/-0.117) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.911 (+/-0.057) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.888 (+/-0.087) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 15}
# 0.878 (+/-0.102) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 20}
# 0.900 (+/-0.064) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.903 (+/-0.058) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.893 (+/-0.076) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.893 (+/-0.076) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.890 (+/-0.084) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.880 (+/-0.100) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.897 (+/-0.092) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.897 (+/-0.092) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 10, 'min_samples_split': 4}
# 0.897 (+/-0.092) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 10, 'min_samples_split': 5}
# 0.897 (+/-0.092) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.910 (+/-0.085) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 10, 'min_samples_split': 15}
# 0.910 (+/-0.085) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.895 (+/-0.082) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 2}
# 0.895 (+/-0.082) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 4}
# 0.895 (+/-0.082) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 5}
# 0.895 (+/-0.082) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 10}
# 0.895 (+/-0.082) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 15}
# 0.895 (+/-0.082) for {'max_depth': 10, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 20}
# 0.898 (+/-0.090) for {'max_depth': 10, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.887 (+/-0.087) for {'max_depth': 10, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.909 (+/-0.080) for {'max_depth': 10, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.899 (+/-0.067) for {'max_depth': 10, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.898 (+/-0.082) for {'max_depth': 10, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 15}
# 0.889 (+/-0.102) for {'max_depth': 10, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.909 (+/-0.080) for {'max_depth': 10, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.908 (+/-0.080) for {'max_depth': 10, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 4}
# 0.898 (+/-0.090) for {'max_depth': 10, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.905 (+/-0.056) for {'max_depth': 10, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0
for {'max_depth': 100, 'min_impurity_decrease': 0, 'min_samples_leaf': 10, 'min_samples_split': 15}
# 0.897 (+/-0.092) for {'max_depth': 100, 'min_impurity_decrease': 0, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 2}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 4}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 5}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 10}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 15}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0, 'min_samples_leaf': 15, 'min_samples_split': 20}
# 0.915 (+/-0.053) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.920 (+/-0.039) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.908 (+/-0.080) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.898 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.898 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 15}
# 0.878 (+/-0.102) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.898 (+/-0.090) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.896 (+/-0.083) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 4}
# 0.905 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.898 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.898 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 15}
# 0.878 (+/-0.102) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 2, 'min_samples_split': 20}
# 0.898 (+/-0.067) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.900 (+/-0.062) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.900 (+/-0.062) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.895 (+/-0.081) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.903 (+/-0.060) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.886 (+/-0.100) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.897 (+/-0.092) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.897 (+/-0.092) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 10, 'min_samples_split': 4}
# 0.910 (+/-0.085) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 10, 'min_samples_split': 5}
# 0.910 (+/-0.085) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.897 (+/-0.092) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 10, 'min_samples_split': 15}
# 0.897 (+/-0.092) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 2}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 4}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 5}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 10}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 15}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 20}
# 0.913 (+/-0.103) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.901 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.901 (+/-0.092) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.897 (+/-0.121) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.892 (+/-0.098) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 15}
# 0.896 (+/-0.114) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.896 (+/-0.132) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.907 (+/-0.084) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 4}
# 0.913 (+/-0.033) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.900 (+/-0.071) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.889 (+/-0.114) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 15}
# 0.889 (+/-0.102) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 20}
# 0.893 (+/-0.075) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.896 (+/-0.072) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.904 (+/-0.061) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.904 (+/-0.061) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.892 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.880 (+/-0.100) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.897 (+/-0.092) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.910 (+/-0.085) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 4}
# 0.910 (+/-0.085) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 5}
# 0.910 (+/-0.085) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.897 (+/-0.092) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 15}
# 0.910 (+/-0.085) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 2}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 4}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 5}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 10}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 15}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 20}
# 0.891 (+/-0.112) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.915 (+/-0.095) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.919 (+/-0.061) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.915 (+/-0.064) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.906 (+/-0.081) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 15}
# 0.875 (+/-0.126) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.920 (+/-0.059) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.873 (+/-0.138) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 4}
# 0.912 (+/-0.078) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.876 (+/-0.115) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.889 (+/-0.114) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 15}
# 0.878 (+/-0.102) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 20}
# 0.902 (+/-0.062) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.893 (+/-0.075) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.900 (+/-0.064) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.910 (+/-0.051) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.895 (+/-0.081) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.883 (+/-0.100) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.910 (+/-0.085) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.897 (+/-0.092) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 4}
# 0.910 (+/-0.085) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 5}
# 0.897 (+/-0.092) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.910 (+/-0.085) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 15}
# 0.910 (+/-0.085) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 2}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 4}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 5}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 10}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 15}
# 0.895 (+/-0.082) for {'max_depth': 100, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 20}
# 0.912 (+/-0.101) for {'max_depth': 1000, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.906 (+/-0.078) for {'max_depth': 1000, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.913 (+/-0.085) for {'max_depth': 1000, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.901 (+/-0.120) for {'max_depth': 1000, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.883 (+/-0.124) for {'max_depth': 1000, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 15}
# 0.883 (+/-0.113) for {'max_depth': 1000, 'min_impurity_decrease': 0, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.923 (+/-0.074) for {'max_depth': 1000, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.911 (+/-0.092) for {'max_depth': 1000, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 4}
# 0.909 (+/-0.056) for {'max_depth': 1000, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.899 (+/-0.072) for {'max_depth': 1000, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.888 (+/-0.087) for {'max_depth': 1000, 'min_impurity_decrease': 0, 'min_samples_leaf': 2, 'min_samples_split':
for {'max_depth': 1000, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 5}
# 0.892 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 10}
# 0.892 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 15}
# 0.892 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.01, 'min_samples_leaf': 15, 'min_samples_split': 20}
# 0.910 (+/-0.207) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.903 (+/-0.189) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.894 (+/-0.187) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.891 (+/-0.154) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.898 (+/-0.178) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 15}
# 0.894 (+/-0.180) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.904 (+/-0.179) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.891 (+/-0.182) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 4}
# 0.902 (+/-0.183) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.884 (+/-0.182) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.898 (+/-0.158) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 15}
# 0.896 (+/-0.166) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 2, 'min_samples_split': 20}
# 0.897 (+/-0.175) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.908 (+/-0.164) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.903 (+/-0.161) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.907 (+/-0.183) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.885 (+/-0.178) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.899 (+/-0.155) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.904 (+/-0.183) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.911 (+/-0.167) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 4}
# 0.899 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 5}
# 0.907 (+/-0.171) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.911 (+/-0.167) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 15}
# 0.899 (+/-0.200) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.892 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 2}
# 0.892 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 4}
# 0.892 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 5}
# 0.892 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 10}
# 0.892 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 15}
# 0.892 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.001, 'min_samples_leaf': 15, 'min_samples_split': 20}
# 0.912 (+/-0.175) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.909 (+/-0.171) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.894 (+/-0.196) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.896 (+/-0.171) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.883 (+/-0.194) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 15}
# 0.906 (+/-0.163) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.902 (+/-0.167) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.901 (+/-0.183) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 4}
# 0.902 (+/-0.169) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.892 (+/-0.170) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.884 (+/-0.173) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 15}
# 0.895 (+/-0.165) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 2, 'min_samples_split': 20}
# 0.901 (+/-0.156) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.908 (+/-0.164) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.897 (+/-0.175) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.899 (+/-0.179) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.896 (+/-0.162) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.895 (+/-0.167) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.904 (+/-0.179) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.903 (+/-0.189) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 4}
# 0.904 (+/-0.183) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 5}
# 0.908 (+/-0.171) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.908 (+/-0.168) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 15}
# 0.911 (+/-0.167) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.892 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 2}
# 0.892 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 4}
# 0.892 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 5}
# 0.892 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 10}
# 0.892 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 15}
# 0.892 (+/-0.192) for {'max_depth': 1000, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 15, 'min_samples_split': 20}
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.89       101
#            1       0.93      0.96      0.94       184
#
#     accuracy                           0.93       285
#    macro avg       0.92      0.91      0.92       285
# weighted avg       0.93      0.93      0.93       285
